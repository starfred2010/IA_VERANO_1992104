# %%
#ALFREDO LOPEZ AGUIRRE 1992104 IA ACTIVIDAD 2: EJERCICIOS EN PYTHON
#EJERCICIO 1
nombre=input("ingresa tu nombre:") #usamos funcion input para ingresar datos
print('Hola') #se imprime hola
print(nombre) #se imprime los datos que ingresamos
# Out:
# ingresa tu nombre:Alfredo
# Hola
# Alfredo

# %%
#EJERCICIO 2
lista=[1,2,3,4,5] #creamos una lista 
print(lista) #se imprime la lista
print(lista[4]) #se imprime el indice numero 4 de la lista
lista.reverse() #se utiliza la funcion reverse() para que se revierta la lista
print(lista) #se imprime la lista revertida
# Out:
# [1, 2, 3, 4, 5]
# 5
# [5, 4, 3, 2, 1]

# %%
#EJERCICIO 3
A=["*******","*HOLA *","*A    *","*TODOS*","*ESTO *","*ES   *","*UN   *","*MARCO*","*******"]  #se crea una lista con los datos a mostrar en el output
for X in A: #usando un ciclo for se imprimen todos los datos en A
  print(X) #se imprime x
# Out:
# *******
# *HOLA *
# *A    *
# *TODOS*
# *ESTO *
# *ES   *
# *UN   *
# *MARCO*
# *******
